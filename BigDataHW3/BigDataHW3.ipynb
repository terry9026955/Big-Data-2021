# %%
import pandas as pd
import numpy as np
import math
import csv
import re
import json
import time
from pyspark import SparkContext
from pyspark.sql import SQLContext
import pyspark.sql.functions 
from pyspark.sql import Row
from collections import OrderedDict

# %%
# 爬SGM檔案裡的資料

from bs4 import BeautifulSoup, SoupStrainer


def readData(fileName):
    data = ''
    f = open(fileName, 'rb') #也即 binary mode，read()操作返回的是bytes
    soup = BeautifulSoup(f, 'html.parser')
    
    # 取得body標籤內容
    contents = soup.find_all('body')
    return contents

# %%
#問題一

sTime = time.time()
file = ["000","001","002","003","004","005","006","007","008","009","010","011","012","013","014","015","016","017","018","019","020","021"]
bodyLen, shingleLen = 0, 0
#Shingle儲存
twoShingleSet = set()

#初始設定

print("Start count shingle")
for i in range(len(file)):
    fileName = "C://Users//user//Desktop//reuters21578//reut2-"
    fileName = fileName + file[i] + ".sgm"
    # 讀每個file中的body content
    data = readData(fileName)
    
    # 恢復所有 body content
    for content in data:
        if i < 2:
            bodyLen +=1
        # split one body content by \n
        for d in content.get_text().split("\n"):
            # remove header space and footer space
            sentence = d.strip()
            # regular expresisson
            pat = '[a-zA-Z]+'
            reContent = re.findall(pat, sentence)
            # select two shingle on each time
            for ind in range(len(reContent)-1):
                shingle = reContent[ind] + ' ' + reContent[ind+1]
                # add shingle
                twoShingleSet.add(shingle)
    print("file ", i, " done")
    
    
shingleLen = len(twoShingleSet)
print("Count shingle done\n")
print("Total body number: %d" % bodyLen)
print("Total shingle number: %d" % shingleLen)
print("Count shingle took: %.2fs" % (time.time()-sTime))
# Out:
# Start count shingle
# file  0  done
# file  1  done
# file  2  done
# file  3  done
# file  4  done
# file  5  done
# file  6  done
# file  7  done
# file  8  done
# file  9  done
# file  10  done
# file  11  done
# file  12  done
# file  13  done
# file  14  done
# file  15  done
# file  16  done
# file  17  done
# file  18  done
# file  19  done
# file  20  done
# file  21  done
# Count shingle done
#
# Total body number: 1855
# Total shingle number: 520470
# Count shingle took: 48.44s

# %%
#問題一

#初始設定

sTime = time.time()
file = ["000","001","002","003","004","005","006","007","008","009","010","011","012","013","014","015","016","017","018","019","020","021"]
trueNum = 0
col = 0
pat = '[a-zA-Z]+'
matrix = np.full((shingleLen,bodyLen), False, dtype=bool)


print("Start calculate shingle matrix")
for i in range(2):
    fileName = "C://Users//user//Desktop//reuters21578//reut2-"
    fileName = fileName + file[i] + ".sgm"
    print(fileName +" start!")
    # read body content from each file
    data = readData(fileName)
    contInd = 0
     # save matrix result for each body
    for content in data:
        # save shingle from one body content
        bContShingleSet = set()
        # split one body content by \n
        for d in content.get_text().split("\n"):
            # remove header space and footer space
            sentence = d.strip()
            # regular expresisson
            reContent = re.findall(pat, sentence)
            # select two shingle on each time
            for r in range(len(reContent)-1):
                shingle = reContent[r] + ' ' + reContent[r+1]
                bContShingleSet.add(shingle)
        row = 0
        for t in twoShingleSet:
            if t in bContShingleSet:
                matrix[row][col] = True
                trueNum += 1
            row +=1
        col +=1
        contInd +=1
        if contInd % 100 ==0:
            print(contInd, " done!")

print("col :",col)
print("total trueNum ", trueNum)
print("Calculate shingle matrix done")
print("Calculate shingle matrix took %.2fs" % (time.time()-sTime))

#儲存問題一的內容      
sTime = time.time()
np.savetxt("Q1_Result.csv", matrix, delimiter=",")
print("Save shingle matrix took %.2f" % (time.time()-sTime))
# Out:
# Start calculate shingle matrix
# C://Users//user//Desktop//reuters21578//reut2-000.sgm start!
# 100  done!
# 200  done!
# 300  done!
# 400  done!
# 500  done!
# 600  done!
# 700  done!
# 800  done!
# 900  done!
# C://Users//user//Desktop//reuters21578//reut2-001.sgm start!
# 100  done!
# 200  done!
# 300  done!
# 400  done!
# 500  done!
# 600  done!
# 700  done!
# 800  done!
# 900  done!
# col : 1855
# total trueNum  183231
# Calculate shingle matrix done
# Calculate shingle matrix took 274.33s
# Save shingle matrix took 681.56

# %%
#問題二

#初始設定
sTime = time.time()
index = 0
flag = 0
minHash = np.zeros(bodyLen,int)
idx = np.full(shingleLen, False, dtype=bool)
curNum = 0
ind = 0
mod = 10

print("Start process minHash!")
while index < shingleLen and flag < bodyLen:
    curNum = ind
    index +=1
    if(curNum + mod)< shingleLen:
        ind = curNum + mod
    else:
        ind = (curNum + mod) % shingleLen
    while idx[ind] == True:
        ind += 1
    idx[ind] = True
    for c in range(bodyLen):
        if matrix[ind][c] == True:
            if minHash[c] == 0:
                minHash[c] = index
                flag +=1
    if index % 2000 ==0:
        print("flag ",flag, " done!")
        print("index ", index, " done!")
        
print("Process minHash done!")
print("MinHash calculate took %.2f" % (time.time()-sTime))

#儲存問題二的內容
sTime = time.time()
np.savetxt("Q2_Result.csv", minHash, delimiter=",")
print("Save minHash matrix took %.2fs" % (time.time()-sTime))
# Out:
# Start process minHash!
# flag  485  done!
# index  2000  done!
# flag  783  done!
# index  4000  done!
# flag  992  done!
# index  6000  done!
# flag  1144  done!
# index  8000  done!
# flag  1225  done!
# index  10000  done!
# flag  1299  done!
# index  12000  done!
# flag  1363  done!
# index  14000  done!
# flag  1406  done!
# index  16000  done!
# flag  1448  done!
# index  18000  done!
# flag  1494  done!
# index  20000  done!
# flag  1529  done!
# index  22000  done!
# flag  1558  done!
# index  24000  done!
# flag  1596  done!
# index  26000  done!
# flag  1617  done!
# index  28000  done!
# flag  1632  done!
# index  30000  done!
# flag  1651  done!
# index  32000  done!
# flag  1656  done!
# index  34000  done!
# flag  1665  done!
# index  36000  done!
# flag  1684  done!
# index  38000  done!
# flag  1687  done!
# index  40000  done!
# flag  1699  done!
# index  42000  done!
# flag  1705  done!
# index  44000  done!
# flag  1711  done!
# index  46000  done!
# flag  1715  done!
# index  48000  done!
# flag  1718  done!
# index  50000  done!
# flag  1728  done!
# index  52000  done!
# flag  1732  done!
# index  54000  done!
# flag  1734  done!
# index  56000  done!
# flag  1738  done!
# index  58000  done!
# flag  1741  done!
# index  60000  done!
# flag  1764  done!
# index  62000  done!
# flag  1764  done!
# index  64000  done!
# flag  1767  done!
# index  66000  done!
# flag  1767  done!
# index  68000  done!
# flag  1770  done!
# index  70000  done!
# flag  1773  done!
# index  72000  done!
# flag  1774  done!
# index  74000  done!
# flag  1776  done!
# index  76000  done!
# flag  1778  done!
# index  78000  done!
# flag  1784  done!
# index  80000  done!
# flag  1784  done!
# index  82000  done!
# flag  1784  done!
# index  84000  done!
# flag  1785  done!
# index  86000  done!
# flag  1785  done!
# index  88000  done!
# flag  1785  done!
# index  90000  done!
# flag  1785  done!
# index  92000  done!
# flag  1785  done!
# index  94000  done!
# flag  1786  done!
# index  96000  done!
# flag  1786  done!
# index  98000  done!
# flag  1787  done!
# index  100000  done!
# flag  1788  done!
# index  102000  done!
# flag  1790  done!
# index  104000  done!
# flag  1791  done!
# index  106000  done!
# flag  1805  done!
# index  108000  done!
# flag  1823  done!
# index  110000  done!
# flag  1824  done!
# index  112000  done!
# flag  1824  done!
# index  114000  done!
# flag  1824  done!
# index  116000  done!
# flag  1824  done!
# index  118000  done!
# flag  1824  done!
# index  120000  done!
# flag  1824  done!
# index  122000  done!
# flag  1824  done!
# index  124000  done!
# flag  1824  done!
# index  126000  done!
# flag  1824  done!
# index  128000  done!
# flag  1824  done!
# index  130000  done!
# flag  1824  done!
# index  132000  done!
# flag  1824  done!
# index  134000  done!
# flag  1824  done!
# index  136000  done!
# flag  1836  done!
# index  138000  done!
# flag  1836  done!
# index  140000  done!
# flag  1836  done!
# index  142000  done!
# flag  1837  done!
# index  144000  done!
# flag  1837  done!
# index  146000  done!
# flag  1837  done!
# index  148000  done!
# flag  1837  done!
# index  150000  done!
# flag  1837  done!
# index  152000  done!
# flag  1837  done!
# index  154000  done!
# flag  1837  done!
# index  156000  done!
# flag  1837  done!
# index  158000  done!
# flag  1838  done!
# index  160000  done!
# flag  1838  done!
# index  162000  done!
# flag  1838  done!
# index  164000  done!
# flag  1838  done!
# index  166000  done!
# flag  1838  done!
# index  168000  done!
# flag  1838  done!
# index  170000  done!
# flag  1838  done!
# index  172000  done!
# flag  1838  done!
# index  174000  done!
# flag  1838  done!
# index  176000  done!
# flag  1838  done!
# index  178000  done!
# flag  1838  done!
# index  180000  done!
# flag  1839  done!
# index  182000  done!
# flag  1839  done!
# index  184000  done!
# flag  1839  done!
# index  186000  done!
# flag  1840  done!
# index  188000  done!
# flag  1840  done!
# index  190000  done!
# flag  1851  done!
# index  192000  done!
# flag  1851  done!
# index  194000  done!
# flag  1851  done!
# index  196000  done!
# flag  1851  done!
# index  198000  done!
# flag  1851  done!
# index  200000  done!
# flag  1851  done!
# index  202000  done!
# flag  1851  done!
# index  204000  done!
# flag  1851  done!
# index  206000  done!
# flag  1852  done!
# index  208000  done!
# flag  1852  done!
# index  210000  done!
# flag  1852  done!
# index  212000  done!
# Process minHash done!
# MinHash calculate took 539.26
# Save minHash matrix took 0.01s
